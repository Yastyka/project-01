# %% [markdown]
# # Здравствуйте!
# Откровенно говоря, не очень поняла последовательно в строчку или последовательно в столбик нужно отразить песни, поэтому, сделала два варианта.

# %%
my_favorite_songs = 'Waste a Moment, Staying\' Alive, A Sorta Fairytale, Start Me Up, New Salvation'
my_favorite_songs[:14]+my_favorite_songs[15:-61]+my_favorite_songs[64:]+my_favorite_songs[15:-61]+my_favorite_songs[16:-47]+my_favorite_songs[15:-61]+my_favorite_songs[51:-15]
# Out:
# "Waste a Moment New Salvation Staying' Alive Start Me Up"

# %%
# здесь хотела прописать в одну строчку print(s[0] + s[4] + s[1] + s[3], end = "\n"), но перенос на новую строчку почему-то не сработал, сделала отдельными строками.
my_favorite_songs = 'Waste a Moment, Staying\' Alive, A Sorta Fairytale, Start Me Up, New Salvation'

s = my_favorite_songs.split(',')
print(s[0])
print(s[4])
print(s[1])
print(s[3])
# Out:
# Waste a Moment
#  New Salvation
#  Staying' Alive
#  Start Me Up
